# %%
import pandas as pd
import csv
import numpy as np
import time
import os
timestr = time.strftime("%m%d%Y_%H%m%s")

# %%
pth = '/ctao_shared_data/AHA/jfeng_VET/'
os.listdir(pth)
# Out:
# ['bleeding.types',
#  'bleeding copy.types',
#  'filtered_history_label_columns_98236_VET_3y_event_label.csv']

# %%
history = pd.read_csv(pth+'filtered_history_label_columns_98236_VET_3y_event_label.csv',low_memory=False)

# %%
history.columns
# Out:
# Index(['patient_sk', 'age', 'gender', 'race', 'gender_label', 'race_label',
#        'age_group_label', 'prior_bleeding_label', 'bleeding_label',
#        'intracranial_bleeding_label', 'GI_bleeding_label',
#        'transfusion_code_label', 'revascularization_label',
#        'stenting_vein_graft_label', 'alcoholo_abuse_label', 'anemia_label',
#        'atrial_fibrillation_label', 'cancer_label', 'skin_cancer_label',
#        'CKD_label', 'diabetes_label', 'dyslipidemia_code_label',
#        'heart_failure_label', 'HBP_label', 'acute_ischemic_event_label',
#        'liver_disease_label', 'PAD_label', 'prior_smoke_label',
#        'smoke_disease_label', 'smoke_disease_procedure_label', 'stroke_label',
#        'ACE_inhibitors_label', 'angiotensin_receptor_blockers_label',
#        'beta_blockers_label', 'calcium_antagonists_label', 'NSAID_label',
#        'statins_label', 'bleeding_3y_event_label', 'ischemic_3y_event_label',
#        'VTE'],
#       dtype='object')

# %%
history.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98236 entries, 0 to 98235
# Data columns (total 40 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   patient_sk                           98236 non-null  int64
#  1   age                                  98236 non-null  float64
#  2   gender                               98234 non-null  object
#  3   race                                 98090 non-null  object
#  4   gender_label                         98234 non-null  float64
#  5   race_label                           98090 non-null  float64
#  6   age_group_label                      98236 non-null  int64
#  7   prior_bleeding_label                 98236 non-null  int64
#  8   bleeding_label                       98236 non-null  int64
#  9   intracranial_bleeding_label          98236 non-null  int64
#  10  GI_bleeding_label                    98236 non-null  int64
#  11  transfusion_code_label               98236 non-null  int64
#  12  revascularization_label              98236 non-null  int64
#  13  stenting_vein_graft_label            98236 non-null  int64
#  14  alcoholo_abuse_label                 98236 non-null  int64
#  15  anemia_label                         98236 non-null  int64
#  16  atrial_fibrillation_label            98236 non-null  int64
#  17  cancer_label                         98236 non-null  int64
#  18  skin_cancer_label                    98236 non-null  int64
#  19  CKD_label                            98236 non-null  int64
#  20  diabetes_label                       98236 non-null  int64
#  21  dyslipidemia_code_label              98236 non-null  int64
#  22  heart_failure_label                  98236 non-null  int64
#  23  HBP_label                            98236 non-null  int64
#  24  acute_ischemic_event_label           98236 non-null  int64
#  25  liver_disease_label                  98236 non-null  int64
#  26  PAD_label                            98236 non-null  int64
#  27  prior_smoke_label                    98236 non-null  int64
#  28  smoke_disease_label                  98236 non-null  int64
#  29  smoke_disease_procedure_label        98236 non-null  int64
#  30  stroke_label                         98236 non-null  int64
#  31  ACE_inhibitors_label                 98236 non-null  int64
#  32  angiotensin_receptor_blockers_label  98236 non-null  int64
#  33  beta_blockers_label                  98236 non-null  int64
#  34  calcium_antagonists_label            98236 non-null  int64
#  35  NSAID_label                          98236 non-null  int64
#  36  statins_label                        98236 non-null  int64
#  37  bleeding_3y_event_label              98236 non-null  int64
#  38  ischemic_3y_event_label              98236 non-null  int64
#  39  VTE                                  98236 non-null  int64
# dtypes: float64(3), int64(35), object(2)
# memory usage: 30.0+ MB

# %% [markdown]
# ## Group Race to Other Race

# %%
history.race.value_counts()
# Out:
# Caucasian                 81518
# African American           9532
# Other                      3533
# Asian                      1466
# Native American             809
# Hispanic                    590
# Unknown                     393
# Pacific Islander            169
# Mid Eastern Indian           34
# Biracial                     31
# Asian/Pacific Islander       15
# Name: race, dtype: int64

# %%
oth_ls = ['Native American', 'Pacific Islander', 'Asian/Pacific Islander','Biracial', 'Mid Eastern Indian','Other','Unknown']
history['Race'] = np.where(history.race.isin(oth_ls),'Other',history.race)
history.Race.value_counts()
# Out:
# Caucasian           81518
# African American     9532
# Other                4984
# Asian                1466
# Hispanic              590
# Name: Race, dtype: int64

# %%
history['patient_sk']=history['patient_sk'].astype(str)
history['age'] = history['age'].astype(int)

# %%
history.race_label.value_counts()
# Out:
# 0.0    81518
# 1.0     9532
# 5.0     3782
# 3.0     1466
# 2.0      809
# 4.0      590
# 6.0      393
# Name: race_label, dtype: int64

# %%
history = history.drop(columns=['gender_label','race_label','race']).reset_index(drop=True)

# %%
history = pd.get_dummies(data = history, columns=['Race','gender'])

# %%
history.columns
# Out:
# Index(['patient_sk', 'age', 'age_group_label', 'prior_bleeding_label',
#        'bleeding_label', 'intracranial_bleeding_label', 'GI_bleeding_label',
#        'transfusion_code_label', 'revascularization_label',
#        'stenting_vein_graft_label', 'alcoholo_abuse_label', 'anemia_label',
#        'atrial_fibrillation_label', 'cancer_label', 'skin_cancer_label',
#        'CKD_label', 'diabetes_label', 'dyslipidemia_code_label',
#        'heart_failure_label', 'HBP_label', 'acute_ischemic_event_label',
#        'liver_disease_label', 'PAD_label', 'prior_smoke_label',
#        'smoke_disease_label', 'smoke_disease_procedure_label', 'stroke_label',
#        'ACE_inhibitors_label', 'angiotensin_receptor_blockers_label',
#        'beta_blockers_label', 'calcium_antagonists_label', 'NSAID_label',
#        'statins_label', 'bleeding_3y_event_label', 'ischemic_3y_event_label',
#        'VTE', 'Race_African American', 'Race_Asian', 'Race_Caucasian',
#        'Race_Hispanic', 'Race_Other', 'gender_Female', 'gender_Male',
#        'gender_Unknown'],
#       dtype='object')

# %%
history.shape
# Out:
# (98236, 44)

# %%
isch_no = history.loc[history['ischemic_3y_event_label']==0]
isch_yes = history.loc[history['ischemic_3y_event_label']==1]
bld_no = history.loc[history['bleeding_3y_event_label']==0]
bld_yes = history.loc[history['bleeding_3y_event_label']==1]
al_d = {'isch_no':isch_no}
isch_yes_d = {'isch_yes':isch_yes}
bld_no_d = {'bld_no':bld_no}
bld_yes_d = {'bld_yes':bld_yes}

# %%
al_d.update(isch_yes_d)
al_d.update(bld_no_d)
al_d.update(bld_yes_d)

# %%
al_d.keys()
# Out:
# dict_keys(['isch_no', 'isch_yes', 'bld_no', 'bld_yes'])

# %%
count_dict={}
d={}
    
for key in al_d.keys():
    data=pd.DataFrame(al_d[key])
    count_dict[key]={}
    # Age, mean and median
    d['age_mean'] = data['age'].mean()
    d['age_std'] = data['age'].std()
    
    
    
    # Calculate the number of ==1 for each label in the column, and the total count of all patients
    col = list(data.columns)
    for x in col:
        yes = len(data.loc[data[x]==1])
        d[x]=yes
        total = len(data)
        d['total']=total
    
    count_dict[key].update(d)
    
print(count_dict)
# Out:
# {'isch_no': {'age_mean': 64.50349067716265, 'age_std': 12.003262029018238, 'patient_sk': 0, 'total': 69614, 'age': 0, 'age_group_label': 30541, 'prior_bleeding_label': 5460, 'bleeding_label': 4421, 'intracranial_bleeding_label': 156, 'GI_bleeding_label': 1926, 'transfusion_code_label': 1594, 'revascularization_label': 1162, 'stenting_vein_graft_label': 0, 'alcoholo_abuse_label': 849, 'anemia_label': 7533, 'atrial_fibrillation_label': 4785, 'cancer_label': 5913, 'skin_cancer_label': 839, 'CKD_label': 5183, 'diabetes_label': 2373, 'dyslipidemia_code_label': 26450, 'heart_failure_label': 7392, 'HBP_label': 29818, 'acute_ischemic_event_label': 7329, 'liver_disease_label': 16078, 'PAD_label': 9007, 'prior_smoke_label': 10670, 'smoke_disease_label': 10670, 'smoke_disease_procedure_label': 0, 'stroke_label': 2766, 'ACE_inhibitors_label': 9340, 'angiotensin_receptor_blockers_label': 3594, 'beta_blockers_label': 15816, 'calcium_antagonists_label': 8424, 'NSAID_label': 7950, 'statins_label': 13146, 'bleeding_3y_event_label': 9261, 'ischemic_3y_event_label': 0, 'VTE': 1788, 'Race_African American': 6320, 'Race_Asian': 1059, 'Race_Caucasian': 58269, 'Race_Hispanic': 406, 'Race_Other': 3458, 'gender_Female': 24245, 'gender_Male': 45368, 'gender_Unknown': 0}, 'isch_yes': {'age_mean': 64.16553699951086, 'age_std': 12.200661604611533, 'patient_sk': 0, 'total': 28622, 'age': 0, 'age_group_label': 12859, 'prior_bleeding_label': 2862, 'bleeding_label': 2275, 'intracranial_bleeding_label': 106, 'GI_bleeding_label': 1051, 'transfusion_code_label': 977, 'revascularization_label': 537, 'stenting_vein_graft_label': 0, 'alcoholo_abuse_label': 449, 'anemia_label': 4175, 'atrial_fibrillation_label': 2155, 'cancer_label': 2449, 'skin_cancer_label': 409, 'CKD_label': 3349, 'diabetes_label': 1148, 'dyslipidemia_code_label': 12234, 'heart_failure_label': 4249, 'HBP_label': 13975, 'acute_ischemic_event_label': 4956, 'liver_disease_label': 8480, 'PAD_label': 5017, 'prior_smoke_label': 5619, 'smoke_disease_label': 5619, 'smoke_disease_procedure_label': 0, 'stroke_label': 2192, 'ACE_inhibitors_label': 5298, 'angiotensin_receptor_blockers_label': 1864, 'beta_blockers_label': 8389, 'calcium_antagonists_label': 4683, 'NSAID_label': 3968, 'statins_label': 7170, 'bleeding_3y_event_label': 6958, 'ischemic_3y_event_label': 28622, 'VTE': 1120, 'Race_African American': 3212, 'Race_Asian': 407, 'Race_Caucasian': 23249, 'Race_Hispanic': 184, 'Race_Other': 1526, 'gender_Female': 10425, 'gender_Male': 18193, 'gender_Unknown': 3}, 'bld_no': {'age_mean': 63.82528012485216, 'age_std': 11.988329052006893, 'patient_sk': 0, 'total': 82017, 'age': 0, 'age_group_label': 37712, 'prior_bleeding_label': 5430, 'bleeding_label': 4378, 'intracranial_bleeding_label': 189, 'GI_bleeding_label': 1868, 'transfusion_code_label': 1535, 'revascularization_label': 1383, 'stenting_vein_graft_label': 0, 'alcoholo_abuse_label': 927, 'anemia_label': 7943, 'atrial_fibrillation_label': 4964, 'cancer_label': 6160, 'skin_cancer_label': 909, 'CKD_label': 5698, 'diabetes_label': 2575, 'dyslipidemia_code_label': 30603, 'heart_failure_label': 8366, 'HBP_label': 34377, 'acute_ischemic_event_label': 9672, 'liver_disease_label': 18726, 'PAD_label': 10337, 'prior_smoke_label': 12552, 'smoke_disease_label': 12552, 'smoke_disease_procedure_label': 0, 'stroke_label': 3566, 'ACE_inhibitors_label': 11079, 'angiotensin_receptor_blockers_label': 4033, 'beta_blockers_label': 18476, 'calcium_antagonists_label': 9689, 'NSAID_label': 9218, 'statins_label': 15503, 'bleeding_3y_event_label': 0, 'ischemic_3y_event_label': 21664, 'VTE': 1953, 'Race_African American': 7576, 'Race_Asian': 1210, 'Race_Caucasian': 68438, 'Race_Hispanic': 496, 'Race_Other': 4170, 'gender_Female': 28197, 'gender_Male': 53816, 'gender_Unknown': 2}, 'bld_yes': {'age_mean': 67.33670386583637, 'age_std': 12.007068919773454, 'patient_sk': 0, 'total': 16219, 'age': 0, 'age_group_label': 5688, 'prior_bleeding_label': 2892, 'bleeding_label': 2318, 'intracra ...

# %%
r={}
    
for key in count_dict.keys():
    r[key]={}
    total = count_dict[key]['total']
    for name,value in count_dict[key].items():
        dd={}
        dd[name]= value/total
        r[key].update(dd)

# %%
count_dict.keys()
# Out:
# dict_keys(['isch_no', 'isch_yes', 'bld_no', 'bld_yes'])

# %%
count_df = pd.DataFrame.from_dict(count_dict)
r_df = pd.DataFrame.from_dict(r)

# %%
count_df.head()
# Out:
#                  isch_no      isch_yes        bld_no       bld_yes
# age_mean       64.503491     64.165537     63.825280     67.336704
# age_std        12.003262     12.200662     11.988329     12.007069
# patient_sk      0.000000      0.000000      0.000000      0.000000
# total       69614.000000  28622.000000  82017.000000  16219.000000
# age             0.000000      0.000000      0.000000      0.000000

# %%
r_df.head()
# Out:
#              isch_no  isch_yes    bld_no   bld_yes
# age_mean    0.000927  0.002242  0.000778  0.004152
# age_std     0.000172  0.000426  0.000146  0.000740
# patient_sk  0.000000  0.000000  0.000000  0.000000
# total       1.000000  1.000000  1.000000  1.000000
# age         0.000000  0.000000  0.000000  0.000000

# %%
count_df['isch_no_r']=r_df['isch_no']
count_df['isch_yes_r']=r_df['isch_yes']
count_df['bld_no_r']=r_df['bld_no']
count_df['bld_yes_r']=r_df['bld_yes']

# %%
rs_df=count_df[['isch_yes','isch_yes_r','isch_no','isch_no_r','bld_yes','bld_yes_r','bld_no','bld_no_r']]

# %%
rs_df
# Out:
#                                          isch_yes  isch_yes_r       isch_no  \
# age_mean                                64.165537    0.002242     64.503491
# age_std                                 12.200662    0.000426     12.003262
# patient_sk                               0.000000    0.000000      0.000000
# total                                28622.000000    1.000000  69614.000000
# age                                      0.000000    0.000000      0.000000
# age_group_label                      12859.000000    0.449270  30541.000000
# prior_bleeding_label                  2862.000000    0.099993   5460.000000
# bleeding_label                        2275.000000    0.079484   4421.000000
# intracranial_bleeding_label            106.000000    0.003703    156.000000
# GI_bleeding_label                     1051.000000    0.036720   1926.000000
# transfusion_code_label                 977.000000    0.034135   1594.000000
# revascularization_label                537.000000    0.018762   1162.000000
# stenting_vein_graft_label                0.000000    0.000000      0.000000
# alcoholo_abuse_label                   449.000000    0.015687    849.000000
# anemia_label                          4175.000000    0.145867   7533.000000
# atrial_fibrillation_label             2155.000000    0.075292   4785.000000
# cancer_label                          2449.000000    0.085564   5913.000000
# skin_cancer_label                      409.000000    0.014290    839.000000
# CKD_label                             3349.000000    0.117008   5183.000000
# diabetes_label                        1148.000000    0.040109   2373.000000
# dyslipidemia_code_label              12234.000000    0.427433  26450.000000
# heart_failure_label                   4249.000000    0.148452   7392.000000
# HBP_label                            13975.000000    0.488261  29818.000000
# acute_ischemic_event_label            4956.000000    0.173154   7329.000000
# liver_disease_label                   8480.000000    0.296276  16078.000000
# PAD_label                             5017.000000    0.175285   9007.000000
# prior_smoke_label                     5619.000000    0.196318  10670.000000
# smoke_disease_label                   5619.000000    0.196318  10670.000000
# smoke_disease_procedure_label            0.000000    0.000000      0.000000
# stroke_label                          2192.000000    0.076584   2766.000000
# ACE_inhibitors_label                  5298.000000    0.185102   9340.000000
# angiotensin_receptor_blockers_label   1864.000000    0.065125   3594.000000
# beta_blockers_label                   8389.000000    0.293096  15816.000000
# calcium_antagonists_label             4683.000000    0.163615   8424.000000
# NSAID_label                           3968.000000    0.138635   7950.000000
# statins_label                         7170.000000    0.250507  13146.000000
# bleeding_3y_event_label               6958.000000    0.243100   9261.000000
# ischemic_3y_event_label              28622.000000    1.000000      0.000000
# VTE                                   1120.000000    0.039131   1788.000000
# Race_African American                 3212.000000    0.112221   6320.000000
# Race_Asian                             407.000000    0.014220   1059.000000
# Race_Caucasian                       23249.000000    0.812277  58269.000000
# Race_Hispanic                          184.000000    0.006429    406.000000
# Race_Other                            1526.000000    0.053316   3458.000000
# gender_Female                        10425.000000    0.364230  24245.000000
# gender_Male                          18193.000000    0.635630  45368.000000
# gender_Unknown                           3.000000    0.000105      0.000000
#
#                                      isch_no_r       bld_yes  bld_yes_r  \
# age_mean                              0.000927     67.336704   0.004152
# age_std                               0.000172     12.007069   0.000740
# patient_sk                            0.000000      0.000000   0.000000
# total                                 1.000000  16219.000000   1.000000
# age                                   0.000000      0.000000   0.000000
# age_group_label                       0.438719   5688.000000   0.350700
# prior_bleeding_label                  0.078432   2892.000000   0.178309
# bleeding_label                        0.063507   2318.000000   0.142919
# intracranial_bleeding_label           0.002241     73.000000   0.004501
# GI_bleeding_label                     0.027667   1109.000000   0.068377
# transfusion_code_label                0.022898   1036.000000   0.063876
# revascularization_label               0.016692    316.000000   0.019483
# stenting_vein_graft_label             0.000000      0.000000   0.000000
# alcoholo_abuse_label                  0.012196    371.000000   0.022874
# anemia_label                          0.108211   3765.000000   0.232135
# atrial_fibrillation_label             0.068736   1976.000000   0.121832
# cancer_label                          0.084940   2202.000000   0.135767
# skin_cancer_label                     0.012052    339.000000   0.020901
# CKD_label                             0.074453   2834.000000   0.174733
# diabetes_label                        0.034088    946.000000   0.058327
# dyslipidemia_code_label               0.379952   8081.000000   0.498243
# heart_failure_label                   0.106186   3275.000000   0.201924
# HBP_label                             0.428333   9416.000000   0.580554
# acute_ischemic_event_label            0.105281   2613.000000   0.161107
# liver_disease_label                   0.230959   5832.000000   0.359578
# PAD_label                             0.129385   3687.000000   0.227326
# prior_smoke_label                     0.153274   3737.000000   0.230409
# smoke_disease_label                   0.153274   3737.000000   0.230409
# smoke_disease_procedure_label         0.000000      0.000000   0.000000
# stroke_label                          0.039733   1392.000000   0.085825
# ACE_inhibitors_label                  0.134168   3559.000000   0.219434
# angiotensin_receptor_blockers_label   0.051628   1425.000000   0.087860
# beta_blockers_label                   0.227196   5729.000000   0.353228
# calcium_antagonists_label             0.121010   3418.000000   0.210740
# NSAID_label                           0.114201   2700.000000   0.166471
# statins_label                         0.188841   4813.000000   0.296751
# bleeding_3y_event_label               0.133034  16219.000000   1.000000
# ischemic_3y_event_label               0.000000   6958.000000   0.429003
# VTE                                   0.025684    955.000000   0.058882
# Race_African American                 0.090786   1956.000000   0.120599
# Race_Asian                            0.015212    256.000000   0.015784
# Race_Caucasian                        0.837030  13080.000000   0.806462
# Race_Hispanic                         0.005832     94.000000   0.005796
# Race_Other                            0.049674    814.000000   0.050188
# gender_Female                         0.348278   6473.000000   0.399100
# gender_Male                           0.651708   9745.000000   0.600839
# gender_Unknown                        0.000000      1.000000   0.000062
#
#                                            bld_no  bld_no_r
# age_mean                                63.825280  0.000778
# age_std                                 11.988329  0.000146
# patient_sk                               0.000000  0.000000
# total                                82017.000000  1.000000
# age                                      0.000000  0.000000
# age_group_label                      37712.000000  0.459807
# prior_bleeding_label                  5430.000000  0.066206
# bleeding_label                        4378.000000  0.053379
# intracranial_bleeding_label            189.000000  0.002304
# GI_bleeding_label                     1868.000000  0.022776
# transfusion_code_label                1535.000000  0.018716
# revascularization_label               1383.000000  0.016862
# stenting_vein_graft_label                0.000000  0.000000
# alcoholo_abuse_label                   927.000000  0.011303
# anemia_label                          7943.000000  0.096846
# atrial_fibrillation_label             4964.000000  0.060524
# cancer_label                          6160.000000  0.075106
# skin_cancer_label                      909.000000  0.011083
# CKD_label                             5698.000000  0.069473
# diabetes_label                        2575.000000  0.031396
# dyslipidemia_code_label              30603.000000  0.373130
# heart_failure_label                   8366.000000  0.102003
# HBP_label                            34377.000000  0.419145
# acute_ischemic_event_label            9672.000000  0.117927
# liver_disease_label                  18726.000000  0.228319
# PAD_label                            10337.000000  0.126035
# prior_smoke_label                    12552.000000  0.153041
# smoke_disease_label                  12552.000000  0.153041
# smoke_disease_procedure_label            0.000000  0.000000
# stroke_label                          3566.000000  0.043479
# ACE_inhibitors_label                 11079.000000  0.135082
# angiotensin_receptor_blockers_label   4033.000000  0.049173
# beta_blockers_label                  18476.000000  0.225270
# calcium_antagonists_label             9689.000000  0.118134
# NSAID_label                           9218.000000  0.112391
# statins_label                        15503.000000  0.189022
# bleeding_3y_event_label                  0.000000  0.000000
# ischemic_3y_event_label              21664.000000  0.264140
# VTE                                   1953.000000  0.023812
# Race_African American                 7576.000000  0.092371
# Race_Asian                            1210.000000  0.014753
# Race_Caucasian                       68438.000000  0.834437
# Race_Hispanic                          496.000000  0.006048
# Race_Other                            4170.000000  0.050843
# gender_Female                        28197.000000  0.343795
# gender_Male                          53816.000000  0.656157
# gender_Unknown                           2.000000  0.000024

# %%
rs_df.style.format({'isch_no': "{:.0f}", 'isch_no_r': '{0:.1}',
                   'isch_yes': "{:.0f}", 'isch_yes_r': '{0:.1}',
                   'bld_no': "{:.0f}", 'bld_no_r': '{0:.1}',
                   'bld_yes': "{:.0f}", 'bld_yes_r': '{0:.1}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_21e7d762_ac85_11ed_a1ca_41eb62232745" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >isch_yes</th>        <th class="col_heading level0 col1" >isch_yes_r</th>        <th class="col_heading level0 col2" >isch_no</th>        <th class="col_heading level0 col3" >isch_no_r</th>        <th class="col_heading level0 col4" >bld_yes</th>        <th class="col_heading level0 col5" >bld_yes_r</th>        <th class="col_heading level0 col6" >bld_no</th>        <th class="col_heading level0 col7" >bld_no_r</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row0" class="row_heading level0 row0" >age_mean</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col0" class="data row0 col0" >64</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col1" class="data row0 col1" >0.002</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col2" class="data row0 col2" >65</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col3" class="data row0 col3" >0.0009</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col4" class="data row0 col4" >67</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col5" class="data row0 col5" >0.004</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col6" class="data row0 col6" >64</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row0_col7" class="data row0 col7" >0.0008</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row1" class="row_heading level0 row1" >age_std</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col1" class="data row1 col1" >0.0004</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col2" class="data row1 col2" >12</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col3" class="data row1 col3" >0.0002</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col4" class="data row1 col4" >12</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col5" class="data row1 col5" >0.0007</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col6" class="data row1 col6" >12</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row1_col7" class="data row1 col7" >0.0001</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row2" class="row_heading level0 row2" >patient_sk</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col1" class="data row2 col1" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col2" class="data row2 col2" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col3" class="data row2 col3" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col4" class="data row2 col4" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col5" class="data row2 col5" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row2_col7" class="data row2 col7" >0e+00</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row3" class="row_heading level0 row3" >total</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col0" class="data row3 col0" >28622</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col1" class="data row3 col1" >1e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col2" class="data row3 col2" >69614</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col3" class="data row3 col3" >1e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col4" class="data row3 col4" >16219</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col5" class="data row3 col5" >1e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col6" class="data row3 col6" >82017</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row3_col7" class="data row3 col7" >1e+00</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row4" class="row_heading level0 row4" >age</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col1" class="data row4 col1" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col2" class="data row4 col2" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col3" class="data row4 col3" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col4" class="data row4 col4" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col5" class="data row4 col5" >0e+00</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col6" class="data row4 col6" >0</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row4_col7" class="data row4 col7" >0e+00</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row5" class="row_heading level0 row5" >age_group_label</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col0" class="data row5 col0" >12859</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col1" class="data row5 col1" >0.4</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col2" class="data row5 col2" >30541</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col3" class="data row5 col3" >0.4</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col4" class="data row5 col4" >5688</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col5" class="data row5 col5" >0.4</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col6" class="data row5 col6" >37712</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row5_col7" class="data row5 col7" >0.5</td>
#             </tr>
#             <tr>
#                         <th id="T_21e7d762_ac85_11ed_a1ca_41eb62232745level0_row6" class="row_heading level0 row6" >prior_bleeding_label</th>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col0" class="data row6 col0" >2862</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col1" class="data row6 col1" >0.1</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col2" class="data row6 col2" >5460</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col3" class="data row6 col3" >0.08</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col4" class="data row6 col4" >2892</td>
#                         <td id="T_21e7d762_ac85_11ed_a1ca_41eb62232745row6_col5" class="data row6 col5" >0.2</td>

# %%
rs_df.to_csv('./out_table1_AHA_90K_{}_3y.csv'.format(timestr))
